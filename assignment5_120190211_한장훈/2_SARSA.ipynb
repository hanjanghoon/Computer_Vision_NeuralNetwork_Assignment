# %%
import numpy as np

# %% [markdown]
# ## SARSA(On-Policy TD Control)

# %% [markdown]
# same in "2_MC Control agent.ipynb"

# %%
class Env:
    def __init__(self):
        self.grid_width = 5
        self.grid_height = self.grid_width
        self.action_grid = [(-1, 0), (1, 0), (0, -1), (0, 1)]     # U, D, L, R
        self.gtriangle1 = [1, 2]
        self.gtriangle2 = [2, 1]
        self.goal = [2, 2]
        
    def step(self, state, action):
        x, y = state
        
        # get next state by action
        x+= action[0]
        y+= action[1]
        
        if x < 0 :
            x = 0
        elif x > (self.grid_width-1) :
            x = (self.grid_width-1)

        if y < 0 :
            y = 0
        elif y > (self.grid_width-1) :
            y = (self.grid_width-1)
        
        next_state = [x, y]
        
        # reward 
        if next_state == self.gtriangle1 or next_state == self.gtriangle2:
            reward = -1
            done = True
        elif next_state == self.goal:
            reward = 1
            done = True
        else:
            reward = 0
            done = False
        
        return next_state, reward, done
    
    def reset(self):
        return [0, 0]

# %%
class SARSA_agent:
    def __init__(self):
        self.action_grid = [(-1, 0), (1, 0), (0, -1), (0, 1)]
        self.action_text= ['U', 'D', 'L', 'R']
        self.grid_width = 5
        self.grid_height = self.grid_width
        self.Qtable = np.zeros((self.grid_width, self.grid_height, len(self.action_grid)))
        self.e = .1
        self.learning_rate = .01
        self.discount_factor = .95
        self.memory=[]
    
    def get_action(self, state):
        # with prob.ε take random action
        if np.random.randn() <  self.e :
            idx = np.random.choice(len(self.action_grid),1)[0]
        else :
            Qvalues = self.Qtable[tuple(state)]
            maxQ = np.amax(Qvalues)
            tie_Qchecker = np.where(Qvalues==maxQ)[0]
            
            # if tie max value, get random
            if len(tie_Qchecker) > 1:
                idx = np.random.choice(tie_Qchecker, 1)[0]
            else :
                idx = np.argmax(Qvalues)
                
        action = self.action_grid[idx]
        return action    
        
    # using First visit MC    
    def update(self, state, action, reward, next_state, next_action):
        action_idx = self.action_grid.index(action)
        next_action_idx = self.action_grid.index(next_action)
        current_Q = self.Qtable[tuple(state)][action_idx]
        next_Q = self.Qtable[tuple(next_state)][next_action_idx]
        updated_Q = current_Q + self.learning_rate*((reward + self.discount_factor*next_Q)-current_Q)
        self.Qtable[tuple(state)][action_idx] = updated_Q
        
    def save_actionseq(self, action_sequence, action):
        idx = self.action_grid.index(action)
        action_sequence.append(self.action_text[idx])

# %%
if __name__ =='__main__':
    env = Env()
    agent = SARSA_agent()
    total_episode = 10000
    sr = 0
    
    for episode in range(total_episode):
        action_sequence=[]
        total_reward = 0
        walk = 0
        
        # initial state, action, done
        state = env.reset()
        action = agent.get_action(state)
        done = False
        
        while not done:  
            agent.save_actionseq(action_sequence, action)
            
            # next state, action
            next_state, reward, done = env.step(state, action)
            next_action = agent.get_action(next_state)

            # update Qtable
            agent.update(state, action, reward, next_state, next_action)
            
            total_reward += reward
            state = next_state
            action = agent.get_action(state)
            
            if done:
                if episode % 100 == 0:
                    print('finished at', next_state)
                    print('episode :{}, The number of step:{}\n The sequence of action is:\
                          {}\nThe total reward is: {}\n'.format(episode, walk, action_sequence, total_reward))
                if state == env.goal:
                    sr += 1
                break

            
            
            
print('The accuracy :', sr/total_episode*100, '%')
# Out:
# finished at [1, 2]
# episode :0, The number of step:0
#  The sequence of action is:                          ['D', 'R', 'R']
# The total reward is: -1
#
# finished at [2, 2]
# episode :100, The number of step:0
#  The sequence of action is:                          ['L', 'U', 'U', 'L', 'U', 'U', 'R', 'L', 'U', 'U', 'U', 'L', 'R', 'R', 'R', 'R', 'D', 'L', 'D', 'D', 'U', 'R', 'U', 'L', 'U', 'U', 'R', 'D', 'R', 'L', 'D', 'L']
# The total reward is: 1
#
# finished at [1, 2]
# episode :200, The number of step:0
#  The sequence of action is:                          ['L', 'U', 'L', 'D', 'R', 'U', 'L', 'U', 'D', 'U', 'D', 'R', 'R']
# The total reward is: -1
#
# finished at [2, 2]
# episode :300, The number of step:0
#  The sequence of action is:                          ['U', 'U', 'U', 'D', 'U', 'R', 'L', 'U', 'R', 'L', 'R', 'L', 'L', 'U', 'L', 'U', 'L', 'U', 'U', 'U', 'R', 'L', 'D', 'U', 'R', 'U', 'L', 'L', 'U', 'R', 'L', 'U', 'U', 'U', 'R', 'L', 'U', 'U', 'U', 'R', 'L', 'U', 'U', 'U', 'U', 'U', 'U', 'U', 'U', 'D', 'D', 'D', 'D', 'R', 'L', 'U', 'D', 'U', 'D', 'R', 'L', 'L', 'U', 'D', 'R', 'U', 'R', 'U']
# The total reward is: 1
#
# finished at [2, 2]
# episode :400, The number of step:0
#  The sequence of action is:                          ['D', 'L', 'U', 'L', 'U', 'D', 'L', 'L', 'U', 'L', 'L', 'L', 'L', 'D', 'U', 'R', 'L', 'U', 'U', 'U', 'U', 'R', 'U', 'L', 'D', 'L', 'D', 'D', 'L', 'D', 'R', 'R', 'U', 'U']
# The total reward is: 1
#
# finished at [2, 2]
# episode :500, The number of step:0
#  The sequence of action is:                          ['D', 'L', 'U', 'L', 'L', 'U', 'L', 'L', 'L', 'D', 'U', 'L', 'R', 'L', 'D', 'D', 'D', 'U', 'D', 'D', 'U', 'L', 'D', 'D', 'R', 'D', 'R', 'R', 'L', 'L', 'R', 'D', 'L', 'L', 'R', 'R', 'U', 'D', 'U', 'L', 'D', 'D', 'R', 'R', 'R', 'L', 'U', 'L', 'U']
# The total reward is: 1
#
# finished at [2, 1]
# episode :600, The number of step:0
#  The sequence of action is:                          ['U', 'L', 'L', 'D', 'U', 'R', 'L', 'L', 'U', 'L', 'L', 'D', 'U', 'R', 'L', 'R', 'L', 'U', 'U', 'R', 'U', 'D', 'L', 'D', 'U', 'D', 'D', 'D', 'R', 'L', 'R', 'U', 'R', 'D', 'U', 'D', 'U', 'L', 'U']
# The total reward is: -1
#
# finished at [1, 2]
# episode :700, The number of step:0
#  The sequence of action is:                          ['R', 'U', 'U', 'U', 'R', 'D']
# The total reward is: -1
#
# finished at [2, 2]
# episode :800, The number of step:0
#  The sequence of action is:                          ['R', 'L', 'D', 'U', 'R', 'R', 'R', 'D', 'R', 'L', 'D', 'D', 'U', 'L']
# The total reward is: 1
#
# finished at [2, 2]
# episode :900, The number of step:0
#  The sequence of action is:                          ['U', 'D', 'L', 'U', 'D', 'U', 'L', 'U', 'U', 'U', 'L', 'L', 'L', 'D', 'D', 'D', 'D', 'R', 'R', 'L', 'R', 'U', 'U']
# The total reward is: 1
#
# finished at [1, 2]
# episode :1000, The number of step:0
#  The sequence of action is:                          ['L', 'L', 'L', 'L', 'L', 'U', 'R', 'D', 'L', 'L', 'U', 'D', 'L', 'R', 'R']
# The total reward is: -1
#
# finished at [1, 2]
# episode :1100, The number of step:0
#  The sequence of action is:                          ['U', 'L', 'L', 'L', 'U', 'U', 'R', 'U', 'R', 'R', 'D', 'U', 'D', 'L']
# The total reward is: -1
#
# finished at [2, 2]
# episode :1200, The number of step:0
#  The sequence of action is:                          ['L', 'L', 'L', 'R', 'R', 'R', 'D', 'D', 'R', 'L', 'R', 'L', 'L']
# The total reward is: 1
#
# finished at [1, 2]
# episode :1300, The number of step:0
#  The sequence of action is:                          ['U', 'U', 'U', 'L', 'L', 'L', 'R', 'L', 'U', 'U', 'L', 'L', 'R', 'L', 'L', 'L', 'L', 'U', 'R', 'L', 'U', 'R', 'L', 'U', 'D', 'U', 'L', 'L', 'L', 'L', 'U', 'L', 'L', 'L', 'L', 'L', 'L', 'L', 'L', 'L', 'R', 'R', 'R', 'D', 'D', 'R', 'L', 'R', 'L', 'U', 'L']
# The total reward is: -1
#
# finished at [2, 2]
# episode :1400, The number of step:0
#  The sequence of action is:                          ['L', 'U', 'L', 'L', 'L', 'L', 'R', 'R', 'R', 'D', 'R', 'L', 'D', 'L']
# The total reward is: 1
#
# finished at [2, 2]
# episode :1500, The number of step:0
#  The sequence of action is:                          ['U', 'U', 'D', 'U', 'U', 'U', 'U', 'U', 'R', 'R', 'U', 'U', 'U', 'R', 'R', 'D', 'D', 'D', 'U', 'L', 'L']
# The total reward is: 1
#
# finished at [1, 2]
# episode :1600, The number of step:0
#  The sequence of action is:                          ['U', 'U', 'D', 'R', 'L', 'U', 'U', 'D', 'U', 'R', 'R', 'D']
# The total reward is: -1
#
# finished at [2, 2]
# episode :1700, The number of step:0
#  The sequence of action is:                          ['R', 'R', 'R', 'R', 'R', 'D', 'L', 'D', 'L']
# The total reward is: 1
#
# finished at [2, 2]
# episode :1800, The number of step:0
#  The sequence of action is:                          ['L', 'R', 'R', 'R', 'R', 'U', 'D', 'U', 'D', 'L', 'D', 'R', 'L', 'L']
# The total reward is: 1
#
# finished at [2, 2]
# episode :1900, The number of step:0
#  The sequence of action is:                          ['U', 'L', 'U', 'U', 'L', 'U', 'U', 'L', 'D', 'U', 'U', 'D', 'U', 'U', 'D', 'U', 'L', 'R', 'R', 'L', 'L', 'U', 'U', 'R', 'R', 'R', 'D', 'D', 'L']
# The total reward is: 1
#
# finished at [1, 2]
# episode :2000, The number of step:0
#  The sequence of action is:                          ['L', 'L', 'R', 'R', 'L', 'R', 'R', 'U', 'D', 'U', 'D', 'L']
# The total reward is: -1
#
# finished at [2, 2]
# episode :2100, The number of step:0
#  The sequence of action is:                          ['U', 'U', 'U', 'U', 'R', 'U', 'R', 'R', 'D', 'R', 'R', 'U', 'D', 'L', 'D', 'L']
# The total reward is: 1
#
# finished at [2, 2]
# episode :2200, The number of step:0
#  The sequence of action is:                          ['L', 'L', 'L', 'R', 'D', 'U', 'L', 'L', 'D', 'D', 'D', 'R', 'D', 'R', 'L', 'D', 'R', 'U', 'U']
# The total reward is: 1
#
# finished at [2, 1]
# episode :2300, The number of step:0
#  The sequence of action is:                          ['L', 'U', 'L', 'L', 'L', 'U', 'L', 'L', 'D', 'L', 'L', 'D', 'R']
# The total reward is: -1
#
# finished at [2, 2]
# episode :2400, The number of step:0
#  The sequence of action is:                          ['U', 'U', 'D', 'R', 'U', 'L', 'U', 'U', 'D', 'D', 'D', 'R', 'R', 'U']
# The total reward is: 1
#
# finished at [2, 2]
# episode :2500, The number of step:0
#  The sequence of action is:                          ['L', 'L', 'R', 'U', 'L', 'L', 'L', 'L', 'U', 'L', 'L', 'R', 'D', 'L', 'R', 'L', 'D', 'D', 'D', 'L', 'R', 'R', 'U', 'L', 'R', 'U']
# The total reward is: 1
#
# finished at [2, 2]
# episode :2600, The number of step:0
#  The sequence of action is:                          ['L', 'U', 'L', 'L', 'L', 'L', 'L', 'L', 'L', 'L', 'R', 'L', 'U', 'R', 'D', 'U', 'L', 'D', 'D', 'D', 'L', 'R', 'R', 'L', 'R', 'D', 'U', 'U']
# The total reward is: 1
#
# finished at [2, 2]
# episode :2700, The number of step:0
#  The sequence of action is:                          ['L', 'L', 'L', 'L', 'L', 'U', 'U', 'D', 'D', 'D', 'U', 'D', 'R', 'D', 'R', 'U', 'U']
# The total reward is: 1
#
# finished at [2, 2]
# episode :2800, The number of step:0
#  The sequence of action is:                          ['U', 'L', 'U', 'U', 'R', 'L', 'U', 'U', 'D', 'D', 'D', 'R', 'R', 'U']
# The total reward is: 1
#
# finished at [2, 2]
# episode :2900, The number of step:0
#  The sequence of action is:                          ['L', 'R', 'R', 'U', 'R', 'D', 'D', 'L']
# The total reward is: 1
#
# finished at [1, 2]
# episode :3000, The number of step:0
#  The sequence of action is:                          ['L', 'U', 'L', 'L', 'L', 'R', 'R', 'L', 'D', 'R']
# The total reward is: -1
#
# finished at [1, 2]
# episode :3100, The number of step:0
#  The sequence of action is:                          ['U', 'U', 'U', 'U', 'U', 'R', 'R', 'D']
# The total reward is: -1
#
# finished at [2, 1]
# episode :3200, The number of step:0
#  The sequence of action is:                          ['U', 'U', 'D', 'U', 'U', 'U', 'D', 'U', 'U', 'U', 'U', 'U', 'U', 'R', 'L', 'U', 'U', 'U', 'U', 'L', 'L', 'L', 'L', 'L', 'L', 'L', 'L', 'L', 'L', 'L', 'L', 'L', 'D', 'U', 'U', 'R', 'L', 'U', 'D', 'U', 'U', 'R', 'D', 'D']
# The total reward is: -1
#
# finished at [2, 2]
# episode :3300, The number of step:0
#  The sequence of action is:                          ['R', 'U', 'U', 'R', 'R', 'L', 'R', 'D', 'D', 'L']
# The total reward is: 1
#
# finished at [1, 2]
# episode :3400, The number of step:0
#  The sequence of action is:                          ['R', 'L', 'L', 'L', 'R', 'L', 'U', 'U', 'U', 'U', 'U', 'U', 'U', 'U', 'L', 'U', 'U', 'U', 'U', 'D', 'R', 'U', 'R', 'D']
# The total reward is: -1
#
# finished at [2, 2]
# episode :3500, The number of step:0
#  The sequence of action is:                          ['R', 'L', 'U', 'U', 'U', 'L', 'U', 'D', 'D', 'L', 'D', 'R', 'R', 'L', 'L', 'R', 'R', 'R', 'D', 'U', 'U', 'U', 'U', 'D', 'D', 'L']
# The total reward is: 1
#
# finished at [2, 2]
# episode :3600, The number of step:0
#  The sequence of action is:                          ['U', 'U', 'D', 'D', 'U', 'D', 'U', 'D', 'D', 'U', 'D', 'R', 'L', 'R', 'R', 'U']
# The total reward is: 1
#
# finished at [2, 1]
# episode :3700, The number of step:0
#  The sequence of action is:                          ['D', 'D', 'L', 'D', 'R', 'U']
# The total reward is: -1
#
# finished at [2, 2]
# episode :3800, The number of step:0
#  The sequence of action is:                          ['D', 'D', 'U', 'D', 'D', 'R', 'R', 'U']
# The total reward is: 1
#
# finished at [2, 2]
# episode :3900, The number of step:0
#  The sequence of action is:                          ['D', 'D', 'D', 'U', 'D', 'R', 'D', 'D', 'R', 'L', 'R', 'R', 'D', 'L', 'R', 'U', 'U', 'R', 'D', 'R', 'U', 'L', 'D', 'U', 'L']
# The total reward is: 1
#
# finished at [2, 2]
# episode :4000, The number of step:0
#  The sequence of action is:                          ['D', 'D', 'D', 'R', 'R', 'R', 'U', 'L']
# The total reward is: 1
#
# finished at [2, 1]
# episode :4100, The number of step:0
#  The sequence of action is:                          ['R', 'D', 'D']
# The total reward is: -1
#
# finished at [2, 1]
# episode :4200, The number of step:0
#  The sequence of action is:                          ['D', 'D', 'U', 'D', 'R']
# The total reward is: -1
#
# finished at [1, 2]
# episode :4300, The number of step:0
#  The sequence of action is:                          ['D', 'R', 'R']
# The total reward is: -1
#
# finished at [1, 2]
# episode :4400, The number of step:0
#  The sequence of action is:                          ['D', 'U', 'R', 'L', 'U', 'R', 'D', 'U', 'U', 'D', 'U', 'R', 'R', 'L', 'R', 'D', 'L']
# The total reward is: -1
#
# finished at [2, 2]
# episode :4500, The number of step:0
#  The sequence of action is:                          ['U', 'D', 'D', 'D', 'D', 'R', 'R', 'U', 'L', 'R', 'L', 'D', 'L', 'R', 'R', 'U', 'U']
# The total reward is: 1
#
# finished at [2, 2]
# episode :4600, The number of step:0
#  The sequence of action is:                          ['D', 'D', 'U', 'D', 'D', 'U', 'D', 'R', 'R', 'L', 'R', 'D', 'D', 'U', 'U']
# The total reward is: 1
#
# finished at [2, 2]
# episode :4700, The number of step:0
#  The sequence of action is:                          ['D', 'R', 'L', 'D', 'L', 'D', 'R', 'D', 'R', 'R', 'U', 'U', 'L']
# The total reward is: 1
#
# finished at [2, 2]
# episode :4800, The number of step:0
#  The sequence of action is:                          ['D', 'D', 'D', 'R', 'R', 'U']
# The total reward is: 1
#
# finished at [2, 2]
# episode :4900, The number of step:0
#  The sequence of action is:                          ['D', 'D', 'D', 'R', 'D', 'U', 'R', 'U']
# The total reward is: 1
#
# finished at [2, 2]
# episode :5000, The number of step:0
#  The sequence of action is:                          ['D', 'L', 'D', 'D', 'D', 'R', 'L', 'U', 'L', 'R', 'R', 'D', 'U', 'D', 'R', 'U', 'U', 'L']
# The total reward is: 1
#
# finished at [2, 2]
# episode :5100, The number of step:0
#  The sequence of action is:                          ['D', 'D', 'D', 'L', 'R', 'R', 'U']
# The total reward is: 1
#
# finished at [2, 1]
# episode :5200, The number of step:0
#  The sequence of action is:                          ['D', 'R', 'D']
# The total reward is: -1
#
# finished at [2, 2]
# episode :5300, The number of step:0
#  The sequence of action is:                          ['D', 'U', 'U', 'U', 'D', 'L', 'D', 'D', 'R', 'D', 'R', 'U', 'U']
# The total reward is: 1
#
# finished at [2, 1]
# episode :5400, The number of step:0
#  The sequence of action is:                          ['D', 'D', 'R']
# The total reward is: -1
#
# finished at [2, 1]
# episode :5500, The number of step:0
#  The sequence of action is:                          ['D', 'U', 'R', 'L', 'L', 'D', 'D', 'D', 'R', 'R', 'L', 'U']
# The total reward is: -1
#
# finished at [2, 1]
# episode :5600, The number of step:0
#  The sequence of action is:                          ['U', 'D', 'U', 'D', 'U', 'D', 'R', 'D']
# The total reward is: -1
#
# finished at [2, 2]
# episode :5700, The number of step:0
#  The sequence of action is:                          ['D', 'D', 'D', 'R', 'R', 'U']
# The total reward is: 1
#
# finished at [2, 1]
# episode :5800, The number of step:0
#  The sequence of action is:                          ['D', 'U', 'R', 'L', 'D', 'L', 'D', 'R']
# The total reward is: -1
#
# finished at [2, 2]
# episode :5900, The number of step:0
#  The sequence of action is:                          ['U', 'U', 'D', 'D', 'U', 'L', 'D', 'D', 'D', 'R', 'R', 'U', 'D', 'R', 'D', 'U', 'U', 'D', 'U', 'L']
# The total reward is: 1
#
# finished at [2, 1]
# episode :6000, The number of step:0
#  The sequence of action is:                          ['D', 'D', 'R']
# The total reward is: -1
#
# finished at [2, 1]
# episode :6100, The number of step:0
#  The sequence of action is:                          ['U', 'R', 'L', 'D', 'D', 'R']
# The total reward is: -1
#
# finished at [2, 1]
# episode :6200, The number of step:0
#  The sequence of action is:                          ['L', 'L', 'D', 'L', 'D', 'L', 'U', 'L', 'L', 'L', 'D', 'D', 'R', 'U']
# The total reward is: -1
#
# finished at [2, 2]
# episode :6300, The number of step:0
#  The sequence of action is:                          ['L', 'U', 'U', 'D', 'D', 'D', 'R', 'R', 'L', 'R', 'U']
# The total reward is: 1
#
# finished at [2, 2]
# episode :6400, The number of step:0
#  The sequence of action is:                          ['U', 'D', 'D', 'D', 'R', 'D', 'U', 'R', 'R', 'R', 'U', 'L', 'L']
# The total reward is: 1
#
# finished at [2, 2]
# episode :6500, The number of step:0
#  The sequence of action is:                          ['L', 'L', 'D', 'L', 'D', 'D', 'U', 'D', 'R', 'R', 'R', 'U', 'R', 'L', 'U', 'U', 'D', 'D', 'L']
# The total reward is: 1
#
# finished at [2, 1]
# episode :6600, The number of step:0
#  The sequence of action is:                          ['R', 'U', 'L', 'L', 'D', 'D', 'R']
# The total reward is: -1
#
# finished at [2, 1]
# episode :6700, The number of step:0
#  The sequence of action is:                          ['D', 'U', 'L', 'D', 'R', 'D']
# The total reward is: -1
#
# finished at [2, 2]
# episode :6800, The number of step:0
#  The sequence of action is:                          ['D', 'D', 'L', 'D', 'D', 'L', 'R', 'R', 'R', 'U', 'R', 'L', 'L', 'U']
# The total reward is: 1
#
# finished at [2, 2]
# episode :6900, The number of step:0
#  The sequence of action is:                          ['D', 'R', 'L', 'D', 'D', 'R', 'D', 'D', 'R', 'U', 'U']
# The total reward is: 1
#
# finished at [2, 1]
# episode :7000, The number of step:0
#  The sequence of action is:                          ['D', 'D', 'R']
# The total reward is: -1
#
# finished at [2, 2]
# episode :7100, The number of step:0
#  The sequence of action is:                          ['R', 'L', 'D', 'U', 'L', 'D', 'L', 'U', 'U', 'U', 'D', 'L', 'D', 'D', 'R', 'R', 'D', 'U', 'U']
# The total reward is: 1
#
# finished at [2, 2]
# episode :7200, The number of step:0
#  The sequence of action is:                          ['L', 'D', 'D', 'D', 'U', 'L', 'D', 'R', 'R', 'D', 'U', 'D', 'U', 'R', 'R', 'U', 'R', 'R', 'L', 'D', 'U', 'L']
# The total reward is: 1
#
# finished at [2, 1]
# episode :7300, The number of step:0
#  The sequence of action is:                          ['L', 'D', 'D', 'R']
# The total reward is: -1
#
# finished at [2, 2]
# episode :7400, The number of step:0
#  The sequence of action is:                          ['R', 'L', 'D', 'D', 'D', 'R', 'R', 'D', 'U', 'D', 'R', 'D', 'U', 'D', 'U', 'U', 'L']
# The total reward is: 1
#
# finished at [2, 2]
# episode :7500, The number of step:0
#  The sequence of action is:                          ['L', 'R', 'L', 'D', 'U', 'D', 'D', 'U', 'R', 'L', 'D', 'D', 'U', 'U', 'D', 'D', 'U', 'D', 'U', 'U', 'D', 'D', 'R', 'R', 'D', 'L', 'R', 'U', 'U']
# The total reward is: 1
#
# finished at [2, 1]
# episode :7600, The number of step:0
#  The sequence of action is:                          ['U', 'D', 'D', 'D', 'U', 'L', 'R']
# The total reward is: -1
#
# finished at [2, 2]
# episode :7700, The number of step:0
#  The sequence of action is:                          ['D', 'L', 'D', 'L', 'D', 'R', 'R', 'L', 'D', 'R', 'R', 'U', 'R', 'U', 'L', 'R', 'R', 'D', 'D', 'D', 'D', 'L', 'U', 'U', 'U', 'R', 'L', 'U', 'U', 'D', 'D', 'L']
# The total reward is: 1
#
# finished at [2, 2]
# episode :7800, The number of step:0
#  The sequence of action is:                          ['D', 'R', 'L', 'D', 'D', 'D', 'R', 'L', 'R', 'D', 'R', 'L', 'R', 'U', 'U']
# The total reward is: 1
#
# finished at [2, 2]
# episode :7900, The number of step:0
#  The sequence of action is:                          ['U', 'U', 'L', 'L', 'D', 'L', 'D', 'D', 'R', 'R', 'L', 'D', 'R', 'D', 'U', 'U']
# The total reward is: 1
#
# finished at [2, 2]
# episode :8000, The number of step:0
#  The sequence of action is:                          ['D', 'U', 'D', 'U', 'U', 'R', 'D', 'L', 'L', 'D', 'D', 'R', 'R', 'U']
# The total reward is: 1
#
# finished at [1, 2]
# episode :8100, The number of step:0
#  The sequence of action is:                          ['D', 'D', 'U', 'R', 'L', 'D', 'D', 'U', 'D', 'L', 'L', 'R', 'R', 'L', 'D', 'D', 'L', 'R', 'R', 'U', 'R', 'U', 'U', 'L']
# The total reward is: -1
#
# finished at [2, 1]
# episode :8200, The number of step:0
#  The sequence of action is:                          ['D', 'D', 'R']
# The total reward is: -1
#
# finished at [1, 2]
# episode :8300, The number of step:0
#  The sequence of action is:                          ['U', 'R', 'L', 'D', 'R', 'R']
# The total reward is: -1
#
# finished at [2, 2]
# episode :8400, The number of step:0
#  The sequence of action is:                          ['U', 'D', 'D', 'D', 'D', 'R', 'R', 'U', 'U']
# The total reward is: 1
#
# finished at [2, 1]
# episode :8500, The number of step:0
#  The sequence of action is:                          ['R', 'L', 'U', 'U', 'L', 'D', 'D', 'R']
# The total reward is: -1
#
# finished at [2, 2]
# episode :8600, The number of step:0
#  The sequence of action is:                          ['D', 'L', 'D', 'D', 'R', 'R', 'U']
# The total reward is: 1
#
# finished at [2, 1]
# episode :8700, The number of step:0
#  The sequence of action is:                          ['D', 'L', 'D', 'R']
# The total reward is: -1
#
# finished at [2, 1]
# episode :8800, The number of step:0
#  The sequence of action is:                          ['D', 'D', 'R']
# The total reward is: -1
#
# finished at [2, 2]
# episode :8900, The number of step:0
#  The sequence of action is:                          ['U', 'D', 'R', 'L', 'U', 'L', 'D', 'R', 'L', 'L', 'R', 'L', 'D', 'D', 'D', 'D', 'R', 'L', 'R', 'R', 'U', 'R', 'U', 'L']
# The total reward is: 1
#
# finished at [2, 2]
# episode :9000, The number of step:0
#  The sequence of action is:                          ['D', 'R', 'U', 'L', 'D', 'L', 'D', 'D', 'D', 'R', 'L', 'D', 'R', 'L', 'D', 'L', 'L', 'L', 'R', 'R', 'U', 'U']
# The total reward is: 1
#
# finished at [2, 1]
# episode :9100, The number of step:0
#  The sequence of action is:                          ['D', 'U', 'R', 'U', 'D', 'L', 'D', 'R']
# The total reward is: -1
#
# finished at [2, 2]
# episode :9200, The number of step:0
#  The sequence of action is:                          ['L', 'L', 'L', 'L', 'L', 'R', 'L', 'L', 'L', 'L', 'L', 'U', 'L', 'L', 'L', 'L', 'L', 'U', 'R', 'L', 'L', 'U', 'L', 'R', 'L', 'L', 'D', 'U', 'D', 'D', 'D', 'R', 'D', 'D', 'R', 'U', 'U']
# The total reward is: 1
#
# finished at [2, 1]
# episode :9300, The number of step:0
#  The sequence of action is:                          ['D', 'D', 'D', 'D', 'R', 'U', 'U']
# The total reward is: -1
#
# finished at [2, 2]
# episode :9400, The number of step:0
#  The sequence of action is:                          ['D', 'R', 'L', 'D', 'L', 'D', 'R', 'R', 'D', 'L', 'R', 'R', 'D', 'L', 'R', 'R', 'L', 'L', 'U', 'U']
# The total reward is: 1
#
# finished at [1, 2]
# episode :9500, The number of step:0
#  The sequence of action is:                          ['R', 'L', 'R', 'D', 'R']
# The total reward is: -1
#
# finished at [2, 2]
# episode :9600, The number of step:0
#  The sequence of action is:                          ['D', 'R', 'L', 'R', 'L', 'D', 'L', 'D', 'R', 'R', 'U']
# The total reward is: 1
#
# finished at [2, 2]
# episode :9700, The number of step:0
#  The sequence of action is:                          ['U', 'R', 'L', 'D', 'D', 'U', 'U', 'D', 'D', 'D', 'D', 'R', 'D', 'R', 'U', 'U']
# The total reward is: 1
#
# finished at [2, 2]
# episode :9800, The number of step:0
#  The sequence of action is:                          ['D', 'D', 'D', 'D', 'R', 'D', 'R', 'U', 'U']
# The total reward is: 1
#
# finished at [2, 2]
# episode :9900, The number of step:0
#  The sequence of action is:                          ['D', 'L', 'R', 'U', 'R', 'U', 'R', 'D', 'D', 'L']
# The total reward is: 1
#
# The accuracy : 58.120000000000005 %

# %%
agent.Qtable
# Out:
# array([[[-0.03023882, -0.02467009, -0.02837411, -0.06668559],
#         [-0.07930537, -0.26357927, -0.02696578, -0.03617608],
#         [-0.07255643, -0.9848687 , -0.07104253,  0.21381225],
#         [ 0.16530891,  0.27939033, -0.02512164,  0.08539015],
#         [ 0.03108897,  0.17120166,  0.0884156 ,  0.03187485]],
#
#        [[-0.02736856,  0.00101901, -0.03508546, -0.28638021],
#         [-0.07707683, -0.99483772, -0.03218098, -0.99499104],
#         [ 0.        ,  0.        ,  0.        ,  0.        ],
#         [ 0.16530639,  0.71922487, -0.97498984,  0.17194065],
#         [ 0.05434822,  0.26532044,  0.28438648,  0.11537532]],
#
#        [[-0.01787888,  0.31956485,  0.01884917, -0.99999969],
#         [ 0.        ,  0.        ,  0.        ,  0.        ],
#         [ 0.        ,  0.        ,  0.        ,  0.        ],
#         [ 0.28976468,  0.49870141,  1.        ,  0.40044101],
#         [ 0.1288828 ,  0.12448834,  0.70403931,  0.30455484]],
#
#        [[ 0.03141885,  0.40551945,  0.31264187,  0.3092279 ],
#         [-0.99982546,  0.46096951,  0.31201952,  0.75012427],
#         [ 1.        ,  0.58838718,  0.38903029,  0.56188911],
#         [ 0.72476406,  0.31425221,  0.68653094,  0.19995765],
#         [ 0.42628951,  0.04236354,  0.20246219,  0.08677898]],
#
#        [[ 0.29242276,  0.37243487,  0.35630238,  0.48041857],
#         [ 0.36630275,  0.45879711,  0.36823655,  0.5871628 ],
#         [ 0.75562534,  0.5543864 ,  0.44643027,  0.37850888],
#         [ 0.57846271,  0.25353382,  0.43281661,  0.07315713],
#         [ 0.07248335,  0.02700632,  0.28586324,  0.0243502 ]]])

# %%
agent.Qtable[0,1]
# Out:
# array([-0.07930537, -0.26357927, -0.02696578, -0.03617608])

# %%
agent.Qtable[1,1]
# Out:
# array([-0.07707683, -0.99483772, -0.03218098, -0.99499104])

# %%
agent.Qtable[1,0]
# Out:
# array([-0.02736856,  0.00101901, -0.03508546, -0.28638021])
